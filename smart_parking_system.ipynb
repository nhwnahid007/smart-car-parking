# %% [markdown]
# <a href="https://colab.research.google.com/github/nhwnahid007/smart-car-parking/blob/main/smart_parking_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Smart_parking_system.csv')

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E             0    Authorized
# 1     Vehicle Exit  05:17   Exit            -             -     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7             2    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8             3     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D             4    Authorized
# ..             ...    ...    ...          ...           ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50           117    Authorized
# 118   Vehicle Exit  05:32   Exit            -             -     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C           119     Gate Open
# 120   Vehicle Exit  08:05   Exit            -             -     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18           121  Unauthorized
#
# [122 rows x 6 columns]

# %%
import matplotlib.pyplot as plt



event_counts = df['Event'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(event_counts, labels=event_counts.index, autopct='%1.1f%%', startangle=90)
_ = plt.title('Distribution of Vehicle Events')

# %%
df.groupby('Status').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.groupby('Event').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E             0    Authorized
# 1     Vehicle Exit  05:17   Exit            -             -     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7             2    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8             3     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D             4    Authorized
# ..             ...    ...    ...          ...           ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50           117    Authorized
# 118   Vehicle Exit  05:32   Exit            -             -     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C           119     Gate Open
# 120   Vehicle Exit  08:05   Exit            -             -     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18           121  Unauthorized
#
# [122 rows x 6 columns]

# %%
df.groupby('Time')['Status'].value_counts().unstack().plot(kind='line', marker='o')
plt.show()

# %%
for col in df.select_dtypes(include=np.number):
  df[col] = df[col].fillna(0)

print(df.head())
# Out:
#            Event   Time   Gate RFID Card ID Vehicle Count      Status
# 0  Vehicle Entry  22:54  Entry  67 F9 DF 7E             0  Authorized
# 1   Vehicle Exit  05:17   Exit            -             -   Gate Open
# 2  Vehicle Entry  11:36  Entry  99 A0 1F F7             2  Authorized
# 3  Vehicle Entry  11:36  Entry  49 CB 0C C8             3   Gate Open
# 4  Vehicle Entry  10:39  Entry  4E FC E9 6D             4  Authorized

# %%
# df['Time'] = pd.to_datetime(df['Time'])  # Comment out or remove this line

for col in df.select_dtypes(include=np.number):
  df[col] = df[col].fillna(0)

print(df.head())
# Out:
#            Event   Time   Gate RFID Card ID Vehicle Count      Status
# 0  Vehicle Entry  22:54  Entry  67 F9 DF 7E             0  Authorized
# 1   Vehicle Exit  05:17   Exit            -             -   Gate Open
# 2  Vehicle Entry  11:36  Entry  99 A0 1F F7             2  Authorized
# 3  Vehicle Entry  11:36  Entry  49 CB 0C C8             3   Gate Open
# 4  Vehicle Entry  10:39  Entry  4E FC E9 6D             4  Authorized

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E             0    Authorized
# 1     Vehicle Exit  05:17   Exit            -             -     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7             2    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8             3     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D             4    Authorized
# ..             ...    ...    ...          ...           ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50           117    Authorized
# 118   Vehicle Exit  05:32   Exit            -             -     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C           119     Gate Open
# 120   Vehicle Exit  08:05   Exit            -             -     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18           121  Unauthorized
#
# [122 rows x 6 columns]

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E             0    Authorized
# 1     Vehicle Exit  05:17   Exit            -             -     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7             2    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8             3     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D             4    Authorized
# ..             ...    ...    ...          ...           ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50           117    Authorized
# 118   Vehicle Exit  05:32   Exit            -             -     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C           119     Gate Open
# 120   Vehicle Exit  08:05   Exit            -             -     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18           121  Unauthorized
#
# [122 rows x 6 columns]

# %%
df['Vehicle Count'] = pd.to_numeric(df['Vehicle Count'], errors='coerce')
df['Vehicle Count'] = df['Vehicle Count'].fillna(0) # Or any other suitable replacement
df['Vehicle Count'].plot(kind='hist', bins=20, title='Vehicle Count')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID  Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E            0.0    Authorized
# 1     Vehicle Exit  05:17   Exit            -            0.0     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7            2.0    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8            3.0     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D            4.0    Authorized
# ..             ...    ...    ...          ...            ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50          117.0    Authorized
# 118   Vehicle Exit  05:32   Exit            -            0.0     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C          119.0     Gate Open
# 120   Vehicle Exit  08:05   Exit            -            0.0     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18          121.0  Unauthorized
#
# [122 rows x 6 columns]

# %%
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Gate'].value_counts()
    for x_label, grp in df.groupby('Event')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Event')
_ = plt.ylabel('Gate')

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID  Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E            0.0    Authorized
# 1     Vehicle Exit  05:17   Exit            -            0.0     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7            2.0    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8            3.0     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D            4.0    Authorized
# ..             ...    ...    ...          ...            ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50          117.0    Authorized
# 118   Vehicle Exit  05:32   Exit            -            0.0     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C          119.0     Gate Open
# 120   Vehicle Exit  08:05   Exit            -            0.0     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18          121.0  Unauthorized
#
# [122 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def _plot_series(series, series_name, series_index=0):
    """Plots a single series with a specific color from the palette."""
    palette = list(sns.palettes.mpl_palette('Dark2'))
    xs = series['Time']
    ys = series['Vehicle Count']
    plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

downsampled_df = df[df.index % 5 == 0]


fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')

for i, (series_name, series) in enumerate(downsampled_df.groupby('Status')):
    _plot_series(series, series_name, i)

fig.legend(title='Status', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Time')
plt.ylabel('Vehicle Count')
plt.title('Vehicle Count Over Time')
plt.xticks(rotation=45, ha='right')

plt.show()

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID  Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E            0.0    Authorized
# 1     Vehicle Exit  05:17   Exit            -            0.0     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7            2.0    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8            3.0     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D            4.0    Authorized
# ..             ...    ...    ...          ...            ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50          117.0    Authorized
# 118   Vehicle Exit  05:32   Exit            -            0.0     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C          119.0     Gate Open
# 120   Vehicle Exit  08:05   Exit            -            0.0     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18          121.0  Unauthorized
#
# [122 rows x 6 columns]

# %%
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Status'].value_counts()
    for x_label, grp in df.groupby('Gate')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Gate')
_ = plt.ylabel('Status')

# %%
figsize = (12, 1.2 * len(df['Status'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Vehicle Count', y='Status', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-184-a69949f1d92b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Vehicle Count', y='Status', inner='stick', palette='Dark2')

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID  Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E            0.0    Authorized
# 1     Vehicle Exit  05:17   Exit            -            0.0     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7            2.0    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8            3.0     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D            4.0    Authorized
# ..             ...    ...    ...          ...            ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50          117.0    Authorized
# 118   Vehicle Exit  05:32   Exit            -            0.0     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C          119.0     Gate Open
# 120   Vehicle Exit  08:05   Exit            -            0.0     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18          121.0  Unauthorized
#
# [122 rows x 6 columns]

# %%
event_gate_counts = df.groupby(['Gate', 'Event'])['Event'].count().unstack()

event_gate_counts.plot(kind='bar', stacked=True)

plt.xlabel('Gate')
plt.ylabel('Vehicle Count')
plt.title('Vehicle Entry/Exit Distribution by Gate')
_ = plt.legend(title='Event')

# %%
df
# Out:
#              Event   Time   Gate RFID Card ID  Vehicle Count        Status
# 0    Vehicle Entry  22:54  Entry  67 F9 DF 7E            0.0    Authorized
# 1     Vehicle Exit  05:17   Exit            -            0.0     Gate Open
# 2    Vehicle Entry  11:36  Entry  99 A0 1F F7            2.0    Authorized
# 3    Vehicle Entry  11:36  Entry  49 CB 0C C8            3.0     Gate Open
# 4    Vehicle Entry  10:39  Entry  4E FC E9 6D            4.0    Authorized
# ..             ...    ...    ...          ...            ...           ...
# 117  Vehicle Entry  22:53  Entry  C1 FE 2E 50          117.0    Authorized
# 118   Vehicle Exit  05:32   Exit            -            0.0     Gate Open
# 119  Vehicle Entry  02:57  Entry  10 C3 23 6C          119.0     Gate Open
# 120   Vehicle Exit  08:05   Exit            -            0.0     Gate Open
# 121  Vehicle Entry  23:45  Entry  66 A2 04 18          121.0  Unauthorized
#
# [122 rows x 6 columns]

# %%
import pandas as pd

# Create the DataFrame from the provided data
data = {
    'Event': ['Vehicle Entry', 'Vehicle Exit', 'Vehicle Entry', 'Vehicle Entry', 'Vehicle Entry', 'Vehicle Entry'],
    'Time': ['22:54', '05:17', '11:36', '11:36', '10:39', '22:53'],
    'Gate': ['Entry', 'Exit', 'Entry', 'Entry', 'Entry', 'Entry'],
    'RFID Card ID': ['67 F9 DF 7E', '-', '99 A0 1F F7', '49 CB 0C C8', '4E FC E9 6D', 'C1 FE 2E 50'],
    'Vehicle Count': [0.0, 0.0, 2.0, 3.0, 4.0, 117.0],
    'Status': ['Authorized', 'Gate Open', 'Authorized', 'Gate Open', 'Authorized', 'Authorized']
}
df = pd.DataFrame(data)

# Replace with your actual calculated data
top_rfid_cards = {'RFID Card ID': ['67 F9 DF 7E', '99 A0 1F F7', '4E FC E9 6D'], 'Total Vehicle Count': [50, 35, 25]}
avg_time_diff_by_event = {'Event': ['Entry', 'Exit'], 'Average Time Difference (seconds)': [10, 15]}
gate_counts = {'Gate': ['Entry', 'Exit'], 'Vehicle Count': [200, 180]}
max_vehicle_count_time = '14:45'

# Create DataFrames
top_rfid_cards_df = pd.DataFrame(top_rfid_cards)
avg_time_diff_df = pd.DataFrame(avg_time_diff_by_event)
gate_counts_df = pd.DataFrame(gate_counts)
max_vehicle_count_time_df = pd.DataFrame({'Max Vehicle Count Time': [max_vehicle_count_time]})

# Display the DataFrames
print("Top 5 RFID Card IDs with highest vehicle counts:")
display(top_rfid_cards_df)

print("\nAverage time difference for each event type:")
display(avg_time_diff_df)

print("\nNumber of vehicle entries and exits at each gate:")
display(gate_counts_df)

print("\nTime when vehicle count was maximum:")
display(max_vehicle_count_time_df)
# Out:
# Top 5 RFID Card IDs with highest vehicle counts:
#   RFID Card ID  Total Vehicle Count
# 0  67 F9 DF 7E                   50
# 1  99 A0 1F F7                   35
# 2  4E FC E9 6D                   25
# Average time difference for each event type:
#    Event  Average Time Difference (seconds)
# 0  Entry                                 10
# 1   Exit                                 15
# Number of vehicle entries and exits at each gate:
#     Gate  Vehicle Count
# 0  Entry            200
# 1   Exit            180
# Time when vehicle count was maximum:
#   Max Vehicle Count Time
# 0                  14:45

# %%
gate_counts_df = gate_counts_df.T

gate_counts_df.columns = gate_counts_df.iloc[0]
gate_counts_df = gate_counts_df[1:]

gate_counts_df
# Out:
# Gate          Entry Exit
# Vehicle Count   200  180

# %%
df
# Out:
#            Event   Time   Gate RFID Card ID  Vehicle Count      Status
# 0  Vehicle Entry  22:54  Entry  67 F9 DF 7E            0.0  Authorized
# 1   Vehicle Exit  05:17   Exit            -            0.0   Gate Open
# 2  Vehicle Entry  11:36  Entry  99 A0 1F F7            2.0  Authorized
# 3  Vehicle Entry  11:36  Entry  49 CB 0C C8            3.0   Gate Open
# 4  Vehicle Entry  10:39  Entry  4E FC E9 6D            4.0  Authorized
# 5  Vehicle Entry  22:53  Entry  C1 FE 2E 50          117.0  Authorized

# %%
import matplotlib.pyplot as plt

gate_counts_data = {'Gate': ['Entry', 'Exit'],
                   'Entry': [50, 30],
                   'Exit': [40, 60]}

gate_counts_df = pd.DataFrame(gate_counts_data)

plt.figure(figsize=(8, 6))

# Entry in green
plt.bar(gate_counts_df['Gate'], gate_counts_df['Entry'], label='Entry', color='green')
# Exit in red
plt.plot(gate_counts_df['Gate'], gate_counts_df['Exit'], marker='o', linestyle='-', label='Exit', color='red')

plt.xlabel('Gate')
plt.ylabel('Count')
plt.title('Gate Counts by Status')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()
